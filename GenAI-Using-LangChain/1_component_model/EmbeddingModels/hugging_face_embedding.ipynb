# %%
from langchain_huggingface import HuggingFaceEmbeddings

# %%
embeddings = HuggingFaceEmbeddings(
                model_name="BAAI/bge-small-en-v1.5",
                model_kwargs={"device": "cpu"},
                encode_kwargs={"normalize_embeddings": True}
            )

# %%
text = "Islamabad is the capital of Pakistan"
docs = ["Islamabad is the capital of Pakistan",
        "Islamabad is the capital of Pakistan",
        "Islamabad is the capital of Pakistan"
        ]

# %%
vector = embeddings.embed_query(text)
docs_vector = embeddings.embed_documents(docs)

# %%
# print(str(vector))
print(len(vector))
# Out:
# 384

# %%
# print(str(docs_vector))
print(len(docs_vector), "x", len(docs_vector[0]), "x", len(docs_vector[1]), "x", len(docs_vector[2]))
# Out:
# 3 x 384 x 384 x 384
