# %%
import os
from langchain.tools import tool
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from langgraph.checkpoint.memory import InMemorySaver
from pprint import pprint
from dotenv import load_dotenv

os.environ["LANGCHAIN_PROJECT"] = "lca-lc-foundation"

load_dotenv()
# Out:
# True

# %% [markdown]
# ## **No memory**

# %%
agent = create_agent(
    model="gpt-5-nano"
)

# %%
question = HumanMessage(content="Hello, my name is Umer")

response = agent.invoke(
    {"messages": [question]}
)

# %%
pprint(response["messages"][-1].content)
# Out:
# ('Hi Umer! Nice to meet you.\n'
#  '\n'
#  'What would you like help with today? I can:\n'
#  '- Explain topics or concepts\n'
#  '- Draft emails, documents, or essays\n'
#  '- Brainstorm ideas or plans\n'
#  '- Help with math, coding, or problem solving\n'
#  '- Practice a language or learning a new skill\n'
#  '- Just have a chat\n'
#  '\n'
#  'Tell me your goals or the task, and I’ll tailor my response.')

# %%
question = HumanMessage(content="Hey, what is my name?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
pprint(response["messages"][-1].content)
# Out:
# ('I don’t know your name yet. If you tell me what you’d like me to call you '
#  '(your real name, nickname, or something else), I’ll use that in our chat. '
#  'Would you like me to call you by a specific name or nickname?')

# %% [markdown]
# ## **Memory**

# %%
agent = create_agent(
    model="gpt-5-nano",
    checkpointer=InMemorySaver()
)

# %%
question = HumanMessage(content="Hello, my name is Umer?")
config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [question]}, config=config
)

# %%
pprint(response["messages"][-1].content)
# Out:
# ('Hi Umer! Nice to meet you. How can I help you today? If you’d like, I can '
#  'address you as Umer throughout this chat. Are you looking for information, '
#  'help with a task, or just want to chat?')

# %%
question = HumanMessage(content="Hey, what is my name?")
config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [question]}, config=config
)

# %%
pprint(response["messages"][-1].content)
# Out:
# ('Your name is Umer. You told me that earlier, and I’m happy to call you Umer '
#  'throughout this chat. How can I help you today?')
