# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv

# %%
model = init_chat_model(model="gpt-5-nano")

# %%
response = model.invoke("What is the capital of Moon?")

# %%
response.content
# Out:
# 'There’s no capital of the Moon. It’s not a country and has no government.\n\nIf you meant a wordplay puzzle, the capital (uppercase) letter of the word “Moon” is M.\n\nIf you had a fictional universe in mind (a book, show, etc.), tell me which one and I can check what that world calls its capital.'

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'stop',
#  'id': 'chatcmpl-CoMyIBootCSCmaaOZstw4Z59wEl9a',
#  'logprobs': None,
#  'model_name': 'gpt-5-nano-2025-08-07',
#  'model_provider': 'openai',
#  'service_tier': 'default',
#  'system_fingerprint': None,
#  'token_usage': {'completion_tokens': 1745,
#                  'completion_tokens_details': {'accepted_prediction_tokens': 0,
#                                                'audio_tokens': 0,
#                                                'reasoning_tokens': 1664,
#                                                'rejected_prediction_tokens': 0},
#                  'prompt_tokens': 13,
#                  'prompt_tokens_details': {'audio_tokens': 0,
#                                            'cached_tokens': 0},
#                  'total_tokens': 1758}}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="gpt-5-nano",
    temperature=1.0
)
response = model.invoke("What is the capital of Moon?")
response.content
# Out:
# 'There isn’t one. The Moon isn’t a country or sovereign body, so it has no capital. Any future lunar government (if one is established) would choose a capital itself. If you’re thinking of a fictional world, tell me which one and I can name its capital.'

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage, AIMessage, SystemMessage

# %%
agent = create_agent(model="gpt-5-nano")

# %%
response = agent.invoke(
    {"messages": [HumanMessage(content="What is the capital of Moon?")]}
    )

# %%
pprint(response)
# Out:
# {'messages': [HumanMessage(content='What is the capital of Moon?', additional_kwargs={}, response_metadata={}, id='79988bc4-69a1-4ecb-a7ab-000e64f5bb87'),
#               AIMessage(content='There isn’t one. The Moon isn’t a country or government, so it has no capital. If you’re thinking of a fictional work or a proposed lunar settlement, tell me the context and I can suggest a capital name or concept.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 314, 'prompt_tokens': 13, 'total_tokens': 327, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 256, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CoN2qnSB41yrRWXdoS3zwUbz4l98J', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b3504-1593-7aa0-92ca-443e3004d691-0', usage_metadata={'input_tokens': 13, 'output_tokens': 314, 'total_tokens': 327, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 256}})]}

# %%
response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='b45d8b7f-81e1-4b63-9d5c-bc47cf340c73'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='6e9a4925-3243-441d-9785-efeba9bd77b9'),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='417a9a7e-4102-4209-8edf-c026ceb78459'),
#               AIMessage(content='Luna City is a fictional concept (not a real place), but here’s a detailed, story-ready take you can use for worldbuilding, a game, or a short tale.\n\n- What it is\n  - A sprawling metropolis built inside and around a cluster of lunar domes and tunnels, located on the Moon’s near side along a terminator belt for steady sunlight and shade.\n  - The capital of the Moon in the fiction, a hub where colonies, researchers, miners, and tourists converge.\n\n- City layout and vibe\n  - Central core: The Solarium, a sunlit hub with transparent domes, vertical farms, markets, and a calm central plaza where residents gather during “eclipse nights.”\n  - Rings of habitat domes: Residential sectors, research labs, and industry pods arranged in concentric rings connected by a web of transit tubes and maglev rails.\n  - Outer crescent: Industrial and mining districts carved into or around craters, with shielded access points to underground storage and resource processing.\n\n- Government and society\n  - Governance: Lunar Assembly consisting of representatives from settlements, research stations, and mining cooperatives; a Prime Administrator chairs the council.\n  - Law and order: A civil guard called the Crater Guard, trained for zero-G operations, with a strong emphasis on resource sharing and environmental stewardship.\n  - Culture: A blend of pragmatic engineering culture and frontier humor; celebrations include Eclipse Nights, when a solar blackout is observed and data-sharing rituals occur.\n\n- Technology and infrastructure\n  - Life support: Closed-loop systems for air, water, and waste; algae and moss bioreactors for oxygen; hydroponic farms for food.\n  - Energy: Large solar arrays on exposed basalt faces; a compact fusion or fission backup facility; microgrid optimization to handle dust storms and eclipses.\n  - Mobility: Levitated people movers, vacuum-tube maglev shuttles, and personal hopping suits for last-mile travel within domes.\n  - Construction: 3D-printed lunar regolith bricks and inflatable habitats reinforced with graphene composites; radiation shielding using regolith and water tanks.\n\n- Housing and daily life\n  - Dwellings: Single- and multi-family units inside domes with artificial gravity zones, glass-lookouts, and sound-dampened corridors to counter vacuum noise.\n  - Worklife: Researchers, miners, and technicians share shifts in rotating grids; many people live in family clusters that maintain community gardens and schools.\n  - Recreation: Low-gravity sports arenas, zero-G gyms, lunar hiking through tethered craters, and virtual reality halls that simulate Earth environments.\n  - Education: Schools blend hands-on engineering with planetary science, astronomy clubs, and historical studies of Earth–Moon relations.\n\n- Landmarks and neighborhoods\n  - The Glass Spire: The primary communications and weather-control tower, visible from most districts.\n  - Market of Crater Lane: A bustling bazaar of lunar and Earth-made goods, from regolith crafts to Earth-imported foods.\n  - Eclipse Observatory: A famed facility for solar observation, studying solar flares, and guiding power distribution.\n  - Garden Ring and Solarium Park: Green terraces and tree-like sculptures that help stabilize microclimates inside the domes.\n\n- Economy and resources\n  - Key resources: Water ice from shadowed craters, helium-3 and other volatiles from sub-surface mining, and solar energy fed back to Earth or stored for lunar use.\n  - Secondary economy: Tourism flights to the Moon, scientific research contracts, and lunar manufacturing of high-precision components.\n\n- Challenges and conflicts (for drama or plot)\n  - Resource balance: Tensions over water rights, mining quotas, and ecological impact on long-term habitat stability.\n  - Radiation and dust: Protecting infrastructure from solar storms and micrometeorite strikes while keeping costs down.\n  - Autonomy debates: Political friction between  ...

# %% [markdown]
# ## Streaming Output

# %%
for token, metadate in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City in short, the capital of the Moon")]},
    stream_mode="messages"
):
    if token.content:
        print(token.content, end="", flush=True)
# Out:
# Luna City is a fictional idea—the Moon has no real capital. In many sci‑fi works it’s imagined as the lunar “capital” with these short, common traits:
#
# - Status: The seat of lunar governance (a Lunar Council or Commonwealth) and a major hub for Earth–Moon relations in the story world.
# - Location and look: A network of pressurized domes and hollow lava-tube habitats near the equator or along a shielded crater rim, shielded by regolith, with wide glass domes for light.
# - Governance: International or lunar-federation leadership, with laws about mining, water use, air, and residency; often a balance between Earth oversight and local autonomy.
# - Economy and tech: Focus on Minings of water ice and minerals, Helium-3, and high‑level research. Solar farms, robotics, and a lunar port or spaceport as a backbone.
# - Society and life: Multinational settlers, scientists, engineers, and artists; life adapted to 1/6 g, long lunar days/nights, and life-supported habitats with closed-loop systems.
# - Infrastructure: Connected by tunnels, tram or maglev systems, centrifuge stations for artificial gravity, and advanced life-support networks; underground or shielded cores to protect from radiation.
# - Challenges and vibe: Radiation, micrometeoroids, regolith dust, supply-chain fragility, political tensions between Earth and Moon factions, plus the psychological effects of isolation.
# - Flavor variants: In hard sci-fi, it’s a functional, utilitarian capital; in cyberpunk or utopian takes, it can be glittering, crowded, or paradoxically serene.
#
# If you want, tell me the tone (hard sci-fi, hopeful utopia, grim dystopia, adventure hub), and I’ll tailor a compact Luna City concept or write a short lore paragraph.
