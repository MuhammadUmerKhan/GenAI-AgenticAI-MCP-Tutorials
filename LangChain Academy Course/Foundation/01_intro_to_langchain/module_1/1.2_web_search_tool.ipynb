# %%
import os
from langchain.tools import tool
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from tavily import TavilyClient
from typing import Dict, Any
from pprint import pprint
from dotenv import load_dotenv

os.environ["LANGCHAIN_PROJECT"] = "lca-lc-foundation"

load_dotenv()
# Out:
# True

# %% [markdown]
# ## **Without web search**

# %%
agent = create_agent(
    model="gpt-5-nano"
)

# %%
question = HumanMessage(content="How up to date is your training knowledge?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
print(response["messages"][-1].content)
# Out:
# My training data goes up to June 2024. I don’t have real-time internet access by default, so I can’t pull in events or updates that happened after that unless browsing is enabled in your interface. If you need the latest information, I can help you figure out what to look for and how to verify it, or I can browse if the feature is available.

# %% [markdown]
# ## **Add web search tool**

# %%
tavily_client = TavilyClient()

@tool("web_search")
def web_search(query: str) -> Dict[str, Any]:
    """ Search the web for information. """
    return tavily_client.search(query)

# %%
agent = create_agent(
    model="gpt-5-nano",
    tools=[web_search]
)

# %%
question = HumanMessage(content="Who is the current field marshal of Pakistan?")

response = agent.invoke(
    {"messages": [question]}
)

print(response["messages"][-1].content)
# Out:
# As of May 2025, Pakistan’s army chief General Syed Asim Munir has been promoted to field marshal, making him the current (and second) holder of the rank after Ayub Khan.

# %%
pprint(response['messages'])
# Out:
# [HumanMessage(content='Who is the current field marshal of Pakistan?', additional_kwargs={}, response_metadata={}, id='86a57b3f-7bbd-4dff-bfb3-7887670519c2'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 738, 'prompt_tokens': 133, 'total_tokens': 871, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 704, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CoNoIYowzN4AfJvTYrge14gHs1ccS', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b3530-feb0-7a80-a653-a72d726226b8-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'current field marshal of Pakistan Ayub Khan last Field Marshal Pakistan'}, 'id': 'call_ibYprcyzyj8tDMGIiPoysqfm', 'type': 'tool_call'}], usage_metadata={'input_tokens': 133, 'output_tokens': 738, 'total_tokens': 871, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 704}}),
#  ToolMessage(content='{"query": "current field marshal of Pakistan Ayub Khan last Field Marshal Pakistan", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://en.wikipedia.org/wiki/Field_marshal_(Pakistan)", "title": "Field marshal (Pakistan)", "content": "List of appointees ; 1. Muhammad Ayub Khan (1907–1974), October 1959, President of Pakistan (1958–1969) ; 2. Asim Munir (1968-present), 20 May 2025, Chief of ...Read more", "score": 0.7163977, "raw_content": null}, {"url": "https://www.youtube.com/watch?v=IyR3LX61XhI", "title": "Pakistan Elevates Asim Munir to Field Marshal, First Since ...", "content": "Pakistan Elevates Asim Munir to Field Marshal, First Since Ayub Khan | Asim Munir Field Marshal.", "score": 0.6742441, "raw_content": null}, {"url": "https://en.wikipedia.org/wiki/Ayub_Khan", "title": "Ayub Khan", "content": "Field Marshal Mohammad Ayub Khan NPk HJ HPk MBE LoM (14 May 1907 – 19 April 1974) was a Pakistani army officer and military dictator who served as the second ...Read more", "score": 0.61196244, "raw_content": null}, {"url": "https://www.ndtv.com/world-news/before-asim-munir-pakistan-only-had-1-field-marshal-he-became-a-dictator-8467642", "title": "Asim Munir Becomes Pakistan\'s 2nd Field Marshal. First ...", "content": "Asim Munir Becomes Pakistan\'s 2nd Field Marshal. First One Became A Dictator. Pakistan\'s first and only other Field Marshal Muhammad Ayub Khan ...Read more", "score": 0.5914643, "raw_content": null}, {"url": "https://www.thenews.com.pk/print/1313706-pakistan-army-gets-second-field-marshal-after-66-years", "title": "Pakistan Army gets second field marshal after 66 years", "content": "Ayub Khan, a product of the British Royal Military Academy at Sandhurst, took over power through a coup in October 1958, and in 1965, he was ...Read more", "score": 0.57952, "raw_content": null}], "response_time": 0.69, "request_id": "0b1a9f38-a4dc-4be6-83f7-eb0b07f7e77a"}', name='web_search', id='b163e7b1-5089-4440-9558-05589bb4a058', tool_call_id='call_ibYprcyzyj8tDMGIiPoysqfm'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1060, 'prompt_tokens': 761, 'total_tokens': 1821, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1024, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CoNoPOdQ2gjLplscfLe7QtsgUKmL9', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b3531-1bbb-7e61-a093-54262fb4a2ed-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'Asim Munir field marshal 2025 Pakistan May 2025'}, 'id': 'call_LpFakiISTfDfqS4AOBsJJrHL', 'type': 'tool_call'}], usage_metadata={'input_tokens': 761, 'output_tokens': 1060, 'total_tokens': 1821, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1024}}),
#  ToolMessage(content='{"query": "Asim Munir field marshal 2025 Pakistan May 2025", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.youtube.com/watch?v=EUjxKaM38A8", "title": "Pakistan\'s New Dictator Asim Munir | Xplained By NewsX - YouTube", "content": "Asim Munir, appointed Pakistan\'s Chief of Army Staff in 2022, was promoted to Field Marshal in May 2025 and now becomes the constitutionally", "score": 0.85097736, "raw_content": null}, {"url": "https://www.facebook.com/ISPROfficial1/posts/isprrawalpindi-8-december-2025field-marshal-syed-asim-munir-ni-m-hj-chief-of-arm/1292720332884755/", "title": "ISPR Rawalpindi, 8 December 2025 Field Marshal Syed Asim Munir ...", "content": "ISPR Rawalpindi, 24 May 2025: A dinner was hosted by Field Marshal Syed Asim Munir, NI(M), Chief of Army Staff, to honour the political", "score": 0.8156003, "raw_content": null}, {"url": "https://www.aljazeera.com/news/2025/5/21/pakistan-promotes-army-chief-asim-munir-to-field-marshal-why-it-matters", "title": "Pakistan promotes army chief Asim Munir to field marshal - Al Jazeera", "content": "Islamabad, Pakistan – Pakistan\'s cabinet on Tuesday promoted Syed Asim Munir, the country\'s chief of army staff, to the rank of field marshal,", "score": 0.6884899, "raw_content": null}, {"url": "https://www.arabnews.pk/node/2626547/pakistan", "title": "Pakistan\'s military chief Asim Munir in spotlight over Trump\'s Gaza ...", "content": "“He was arrested in May 2025 while attempting to cross from Afghanistan into Pakistan,” Pakistan TV Digital reported, citing intelligence", "score": 0.62906903, "raw_content": null}, {"url": "https://www.jns.org/pakistani-military-chief-set-for-washington-trip-over-gaza-force/", "title": "Pakistani military chief set for Washington trip over Gaza force", "content": "Field Marshal Asim Munir, Pakistan\'s Chief of Defense Forces and Army Staff, is expected to travel to Washington in the coming weeks to", "score": 0.55565286, "raw_content": null}], "response_time": 0.76, "request_id": "fc4b8055-d162-4e47-a744-4468e0aa8abc"}', name='web_search', id='9e06bc6d-9569-47b5-942a-cba89260ed1e', tool_call_id='call_LpFakiISTfDfqS4AOBsJJrHL'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 802, 'prompt_tokens': 1405, 'total_tokens': 2207, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 768, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CoNoYXh5srHzOyoahkiylDxqixZkO', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b3531-3b28-7c50-aeb5-bb62f4eceb74-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'Pakistan field marshal Asim Munir May 2025 Reuters'}, 'id': 'call_h4CFH0bC8LA37HtMWOlBKHvY', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1405, 'output_tokens': 802, 'total_tokens': 2207, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 768}}),
#  ToolMessage(content='{"query": "Pakistan field marshal Asim Munir May 2025 Reuters", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.reuters.com/world/asia-pacific/pakistan-army-chief-asim-munir-be-promoted-field-marshal-rank-2025-05-20/", "title": "Pakistan army chief General Asim Munir promoted to field marshal", "content": "ISLAMABAD , May 20 (Reuters) - Pakistan\'s army chief General Asim Munir will be promoted to the rank of field marshal, the prime minister\'s", "score": 0.8332299, "raw_content": null}, {"url": "https://www.reuters.com/world/asia-pacific/beloved-strongman-support-pakistan-army-chief-surges-after-india-conflict-2025-05-21/", "title": "Support for Pakistan army chief General Asim Munir surges after ...", "content": "Support for Pakistan army chief General Asim Munir surges after India conflict. By Asif Shahzad. May 21, 20259:09 PM UTCUpdated May 21, 2025.", "score": 0.61307496, "raw_content": null}, {"url": "https://www.reuters.com/world/asia-pacific/india-will-not-accept-third-party-mediation-relations-with-pakistan-modi-tells-2025-06-18/", "title": "Trump hosts Pakistani army chief, disagrees with India ... - Reuters", "content": "# Trump hosts Pakistani army chief, disagrees with India over India-Pakistan war mediation. WASHINGTON/ISLAMABAD/NEW DELHI, June 18 (Reuters) - U.S. President Donald Trump hosted Pakistan\'s army chief Field Marshal Asim Munir at the White House on Wednesday in an unprecedented meeting that risked worsening a disagreement with India over the president\'s claim that he stopped last month\'s conflict between the nuclear-armed South Asian foes. White House spokeswoman Anna Kelly said Trump hosted Munir after he called for the president to be nominated for the Nobel Peace Prize for preventing a nuclear war between India and Pakistan. However, Modi told Trump in their call on Tuesday that the ceasefire was achieved through talks between the Indian and Pakistani militaries and not U.S. mediation, India\'s most senior diplomat, Foreign Secretary Vikram Misri, said in a statement. \\"PM Modi told President Trump clearly that during this period, there was no talk at any stage on subjects like India-U.S. trade deal or U.S. mediation between India and Pakistan,\\" Misri said.", "score": 0.61251885, "raw_content": null}, {"url": "https://www.instagram.com/p/DSZbrAkDN6R/", "title": "Pakistan\'s Foreign Office has rejected the Reuters report ... - Instagram", "content": "Pakistan\'s Foreign Office has rejected the Reuters report regarding the planned visit of CDF Field Marshal Asim Munir to US. Read more:", "score": 0.6102915, "raw_content": null}, {"url": "https://www.facebook.com/republicdotpk/posts/reuters-reported-that-us-president-donald-trump-is-pressuring-pakistans-field-ma/876296081563849/", "title": "Reuters reported that US President Donald Trump is pressuring ...", "content": "Field Marshal Asim Munir, Pakistan\'s army chief, is scheduled for a Washington visit in coming weeks to discuss the G+aza initiative with Trump,", "score": 0.5917474, "raw_content": null}], "response_time": 0.57, "request_id": "a7a63aa1-2aef-4188-bc93-21f7aabda6b7"}', name='web_search', id='f106207b-351e-4c77-87c0-71bb52951dcb', tool_call_id='call_h4CFH0bC8LA37HtMWOlBKHvY'),
#  AIMessage(content='As of May 2025, Pakistan’s army chief General Syed Asim Munir has been promoted to field marshal, making him the current (and second) holder of the rank after Ayub Khan.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 883, 'prompt_tokens': 2253, 'total_tokens': 3136, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 832, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CoNofODMbtBHgtaj5TFyqtlfdWwy2', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b3531-579b-7620-9aa6-d6d9b1c9413f-0', usage_metadata={'input_tokens': 2253, 'output_tokens': 883, 'total_tokens': 3136, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 832}})]
